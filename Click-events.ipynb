# %%
from ipywidgets import widgets
import numpy as np
import matplotlib.pyplot as plt

# returns figure object
click_area = plt.subplots()[0]
click_area.canvas.set_window_title('Click here')
text_area = widgets.HTML()

def onclick(event):
    text_area.value = 'xdata=%f, ydata=%f'%(event.xdata, event.ydata)

click_area.canvas.mpl_connect('button_press_event', onclick)
display(text_area)
# Out:
# <img src="data:image/png;base64,..." width="639.7499809339648">

# %%
from ipywidgets import widgets
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import IFrame
import os

filepath = os.path.realpath('./modified.html')
with open(filepath, 'r') as f:
    htmlsample = f.read()
    
# An HTML file is read and is stored in the variable `htmlsample`
# Equivalent to
# htmlsample = "<html><body>Click here</body></html>"

click_area = widgets.HTML(htmlsample)
text_area = widgets.HTML("Co-ordinates will be displayed here")

def onclick(event):
    text_area.value = 'xdata=%f, ydata=%f'% (event.xdata, event.ydata)

click_area.observe(onclick)

display(text_area, click_area)

# %%
print(dir(click_area))
# Out:
# ['_Figure__remove_ax', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_agg_filter', '_alpha', '_animated', '_axobservers', '_axstack', '_cachedRenderer', '_clipon', '_clippath', '_contains', '_dpi', '_gci', '_get_axes', '_get_dpi', '_gid', '_hold', '_label', '_make_key', '_mouseover', '_oid', '_original_dpi', '_path_effects', '_picker', '_prop_order', '_propobservers', '_rasterized', '_remove_method', '_repr_html_', '_set_artist_props', '_set_dpi', '_set_gc_clip', '_sketch', '_snap', '_stale', '_sticky_edges', '_suptitle', '_tight', '_tight_parameters', '_transform', '_transformSet', '_url', '_visible', 'add_axes', 'add_axobserver', 'add_callback', 'add_subplo
# ...

# %%
click_area.trait_events()
# Out:
# {'_comm_changed': <traitlets.traitlets.ObserveHandler at 0x1049d6438>,
#  '_config_changed': <traitlets.traitlets.ObserveHandler at 0x10313cda0>,
#  '_default_keys': <traitlets.traitlets.DefaultHandler at 0x1049d6278>,
#  '_default_layout': <traitlets.traitlets.DefaultHandler at 0x1049e18d0>,
#  '_log_default': <traitlets.traitlets.DefaultHandler at 0x10313cf98>}

# %%
print(widgets.Widget.observe.__doc__)
# Out:
# Setup a handler to be called when a trait changes.
#
#         This is used to setup dynamic notifications of trait changes.
#
#         Parameters
#         ----------
#         handler : callable
#             A callable that is called when a trait changes. Its
#             signature should be ``handler(change)``, where ``change`` is a
#             dictionary. The change dictionary at least holds a 'type' key.
#             * ``type``: the type of notification.
#             Other keys may be passed depending on the value of 'type'. In the
#             case where type is 'change', we also have the following keys:
#             * ``owner`` : the HasTraits instance
#             * ``old`` : the old value of the modified trait attribute
#             * ``new`` : the new value of the modified trait attribute
#             * ``name`` : the name of the modified trait attribute.
#         names : list, str, All
# ...
